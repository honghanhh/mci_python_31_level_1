# %% [markdown]
# ![](https://upload.wikimedia.org/wikipedia/commons/thumb/e/ed/Pandas_logo.svg/1200px-Pandas_logo.svg.png)

# %% [markdown]
# # <center> LESSON 6: Practice with PANDAS </center>

# %% [markdown]
# ## I. Know your dataset

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %%
 #csv: coma-seperates values
#tsv:  tab-seperated values
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'

# %% [markdown]
# ### Step 3. Assign it to a variable called `chipo`.

# %%
chipo = pd.read_csv(url, sep='\t')
#chipo = pd.read_csv('chipo.tsv')
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# ### Step 4. See the first 10 entries

# %% [markdown]
# ### Step 5. What is the number of observations in the dataset?

# %%
chipo.info()

# %%
len(chipo)

# %%
chipo.shape[0]
# Out:
# 4622

# %%
chipo.shape[1]
# Out:
# 5

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %%
chipo.shape[1]
# Out:
# 5

# %% [markdown]
# ### Step 7. Print the name of all the columns.

# %%
chipo.columns.to_list() # eps kieu. list
list
# Out:
# list

# %% [markdown]
# ### Step 8. How is the dataset indexed?

# %%
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %% [markdown]
# ### Step 9. Which was the most-ordered item?

# %%
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
# 1.Quantity per item_name
# 2. item_name has lagest quantity

# %%
# 1.
chipo.groupby('item_name').quantity.sum().reset_index().rename(columns={'quantity':'QUANTITY'})
# Out:
#                                 item_name  QUANTITY
# 0                       6 Pack Soft Drink        55
# 1                           Barbacoa Bowl        66
# 2                        Barbacoa Burrito        91
# 3                   Barbacoa Crispy Tacos        12
# 4                     Barbacoa Salad Bowl        10
# 5                     Barbacoa Soft Tacos        25
# 6                           Bottled Water       211
# 7                                    Bowl         4
# 8                                 Burrito         6
# 9                             Canned Soda       126
# 10                      Canned Soft Drink       351
# 11                          Carnitas Bowl        71
# 12                       Carnitas Burrito        60
# 13                  Carnitas Crispy Tacos         8
# 14                         Carnitas Salad         1
# 15                    Carnitas Salad Bowl         6
# 16                    Carnitas Soft Tacos        40
# ...

# %%
# 2.
chipo.groupby('item_name').quantity.sum().nlargest(1)
# Out:
# item_name
# Chicken Bowl    761
# Name: quantity, dtype: int64

# %%
chipo.groupby('item_name').quantity.sum().nlargest(1).index[0]
# Out:
# 'Chicken Bowl'

# %%
chipo.groupby('item_name').quantity.sum().nsmallest(10)
# Out:
# item_name
# Carnitas Salad                       1
# Chips and Mild Fresh Tomato Salsa    1
# Veggie Crispy Tacos                  1
# Crispy Tacos                         2
# Salad                                2
# Bowl                                 4
# Steak Salad                          4
# Burrito                              6
# Carnitas Salad Bowl                  6
# Veggie Salad                         6
# Name: quantity, dtype: int64

# %%
chipo.groupby('item_name').quantity.sum().nsmallest(10).values[0]
# Out:
# 1

# %%
smallist = chipo.groupby('item_name').quantity.sum().reset_index()
smallist[smallist['quantity'] ==1] # quantity=1
# Out:
#                             item_name  quantity
# 14                     Carnitas Salad         1
# 26  Chips and Mild Fresh Tomato Salsa         1
# 46                Veggie Crispy Tacos         1

# %% [markdown]
# ### Step 10. For the most-ordered item, how many items were ordered?

# %%
chipo.groupby('item_name').quantity.sum().nlargest(1).values[0]
# Out:
# 761

# %%
chipo.groupby('item_name').quantity.sum().sort_values(ascending=False).index[0]
# Out:
# 'Chicken Bowl'

# %%
chipo.groupby('item_name').quantity.sum().sort_values(ascending=False).values[0]
# Out:
# 761

# %% [markdown]
# ### Step 11. What was the most ordered item in the choice_description column?

# %%
chipo.head(10) #NaN-missing vales
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
chipo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
#Missing percentage = sl ban ghi/tong so ban ghi
chipo.isnull().sum()*100/len(chipo)
# Out:
# order_id               0.000000
# quantity               0.000000
# item_name              0.000000
# choice_description    26.958027
# item_price             0.000000
# dtype: float64

# %%
chipo.groupby('choice_description').quantity.sum().nlargest(1).index[0]
# Out:
# '[Diet Coke]'

# %% [markdown]
# ### Step 12. How many items were ordered in total?

# %%
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
len(chipo.item_name.unique()) # tra ve array
# Out:
# 50

# %%
chipo.item_name.nunique()  # nunique -> tra ve so phan tu
# Out:
# 50

# %% [markdown]
# #### Step 13.b. Create a lambda function and change the type of item price

# %%
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %% [markdown]
# #### Step 13.c. Check the item price type

# %%
chipo.info()
chipo.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
type(chipo.item_price.iloc[0])
# Out:
# str

# %%
# convert tu str -> float for item_price
chipo.item_price.iloc[0]
# Out:
# '$2.39 '

# %%
type(float('2.39'))
# Out:
# float

# %%
'$2.39'[1:]
# Out:
# '2.39'

# %%
def convert_type1(x):
    '''
    convert string type to float for values
    
    params:
    
    '''
    return float(x.replace('$','')) # regex -> import re

# %%
def convert_type(x):
    '''
    convert string type to float for values
    
    params:
    
    '''
    return float(x[1:])

# %%
chipo['item_price_float'] = chipo.item_price.apply(convert_type)

# %%
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price  \
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
#
#    item_price_float
# 0              2.39
# 1              3.39
# 2              3.39
# 3              2.39
# 4             16.98

# %%
chipo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
#  5   item_price_float    4622 non-null   float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 216.8+ KB

# %%
# sach: https://bedford-computing.co.uk/learning/wp-content/uploads/2015/10/Python-for-Data-Analysis.pdf

# %%
#Anonymous function
convert_type2 = lambda x: float(x.replace('$','')) #busuness logic
chipo['item_price_float'] = chipo.item_price.apply(convert_type2)
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price  \
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
#
#    item_price_float
# 0              2.39
# 1              3.39
# 2              3.39
# 3              2.39
# 4             16.98

# %%
type(chipo.item_price.iloc[0])
# Out:
# str

# %% [markdown]
# ### Step 14. How much was the revenue for the period in the dataset?

# %%
chipo.item_price_float.sum()
# Out:
# 34500.16

# %% [markdown]
# ### Step 15. How many orders were made in the period?

# %%
chipo.order_id.nunique()
# Out:
# 1834

# %%
len(chipo.order_id.unique())
# Out:
# 1834

# %% [markdown]
# ### Step 16. What is the average revenue amount per order?

# %%
# GT_TB = tong bill / tong so order

# %%
chipo.item_price_float.sum() / chipo.order_id.nunique()
# Out:
# 18.811428571428575

# %% [markdown]
# ### Step 17. How many different items are sold?

# %% [markdown]
# ## II. Filtering & Sorting

# %% [markdown]
# ### Step 18. How many products cost more than $10.00?

# %%
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price  \
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
#
#    item_price_float
# 0              2.39
# 1              3.39
# 2              3.39
# 3              2.39
# 4             16.98

# %%
chipo['price_per_item'] = chipo ['item_price_float'] / chipo['quantity']
chipo.head()

# chipo[chipo['item_price_float'] > 10]
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price  \
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
#
#    item_price_float  price_per_item
# 0              2.39            2.39
# 1              3.39            3.39
# 2              3.39            3.39
# 3              2.39            2.39
# ...

# %%
chipo['price_per_item'] = [x/y for x,y in list(zip ( chipo['item_price_float'], chipo ['quantity']))]
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price  \
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
#
#    item_price_float  price_per_item
# 0              2.39            2.39
# 1              3.39            3.39
# 2              3.39            3.39
# 3              2.39            2.39
# ...

# %%
chipo[chipo['item_price_float'] > 10]
# Out:
#       order_id  quantity           item_name  \
# 4            2         2        Chicken Bowl
# 5            3         1        Chicken Bowl
# 7            4         1       Steak Burrito
# 13           7         1        Chicken Bowl
# 23          12         1     Chicken Burrito
# ...        ...       ...                 ...
# 4610      1830         1       Steak Burrito
# 4611      1830         1      Veggie Burrito
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
#
#                                      choice_description item_price  \
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...    $11.25
# 23    [[Tomatillo-Green Chili Salsa (Medium), Tomati...    $10.98
# ...

# %% [markdown]
# ### Step 19. What is the price of each item?
# ###### Print a data frame with only two columns item_name and item_price

# %%
sample_chipo = chipo[['item_name', 'price_per_item']].drop_duplicates()
sample_chipo[sample_chipo['item_name'] == 'Chicken Bowl']
# Out:
#          item_name  price_per_item
# 4     Chicken Bowl            8.49
# 5     Chicken Bowl           10.98
# 13    Chicken Bowl           11.25
# 19    Chicken Bowl            8.75
# 409   Chicken Bowl           10.98
# 2918  Chicken Bowl            8.19
# 2919  Chicken Bowl           10.58
# 4235  Chicken Bowl            8.50

# %%
chipo.groupby(['item_name', 'choice_description']).price_per_item.mean().to_frame().reset_index()
# Out:
#               item_name                                 choice_description  \
# 0     6 Pack Soft Drink                                             [Coke]
# 1     6 Pack Soft Drink                                        [Diet Coke]
# 2     6 Pack Soft Drink                                         [Lemonade]
# 3     6 Pack Soft Drink                                           [Nestea]
# 4     6 Pack Soft Drink                                           [Sprite]
# ...                 ...                                                ...
# 1854  Veggie Soft Tacos  [Fresh Tomato Salsa, [Black Beans, Cheese, Sou...
# 1855  Veggie Soft Tacos  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...
# 1856  Veggie Soft Tacos  [Roasted Chili Corn Salsa (Medium), [Black Bea...
# 1857  Veggie Soft Tacos  [Roasted Chili Corn Salsa, [Fajita Vegetables,...
# 1858  Veggie Soft Tacos  [Tomatillo Red Chili Salsa, [Fajita Vegetables...
#
#       price_per_item
# 0               6.49
# 1               6.49
# ...

# %%
pd.options.display.max_rows = None
pd.options.display.max_coloums = None
df = chipo.groupby(['item_name', 'choice_description']).price_per_item.mean().to_frame().reset_index()
df.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-02edd9b46243> in <module>
# ----> 1 pd.options.display.max_rows = None
#       2 pd.options.display.max_coloums = None
#       3 df = chipo.groupby(['item_name', 'choice_description']).price_per_item.mean().to_frame().reset_index()
#       4 df.head(5)
#
# NameError: name 'pd' is not defined

# %% [markdown]
# ### Step 20. Sort by the name of the item

# %%
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price  \
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
#
#    item_price_float  price_per_item
# 0              2.39            2.39
# 1              3.39            3.39
# 2              3.39            3.39
# 3              2.39            2.39
# ...

# %%
chipo.sort_values(by=['item_name', 'quantity'], ascending = [False, False]).head(5)
# Out:
#       order_id  quantity          item_name  \
# 3889      1559         2  Veggie Soft Tacos
# 738        304         1  Veggie Soft Tacos
# 781        322         1  Veggie Soft Tacos
# 1395       567         1  Veggie Soft Tacos
# 1699       688         1  Veggie Soft Tacos
#
#                                      choice_description item_price  \
# 3889  [Fresh Tomato Salsa (Mild), [Black Beans, Rice...    $16.98
# 738   [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.25
# 781   [Fresh Tomato Salsa, [Black Beans, Cheese, Sou...     $8.75
# 1395  [Fresh Tomato Salsa (Mild), [Pinto Beans, Rice...     $8.49
# 1699  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...    $11.25
#
#       item_price_float  price_per_item
# 3889             16.98            8.49
# 738              11.25           11.25
# 781               8.75            8.75
# 1395              8.49            8.49
# 1699             11.25           11.25

# %% [markdown]
# ### Step 21. What was the quantity of the most expensive item ordered?

# %%
chipo[chipo.price_per_item ==chipo.price_per_item.max()].groupby('item_name').quantity.sum()
# Out:
# item_name
# Barbacoa Salad Bowl     5
# Carnitas Salad Bowl     4
# Steak Salad Bowl       21
# Name: quantity, dtype: int64

# %% [markdown]
# ### Step 22. How many times was a Veggie Salad Bowl ordered?

# %%
chipo[chipo['item_name'] == 'Veggie Salad Bowl'].order_id.nunique()
# Out:
# 18

# %% [markdown]
# ### Step 23. How many times did someone order more than one Canned Soda?

# %%
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price  \
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
#
#    item_price_float  price_per_item
# 0              2.39            2.39
# 1              3.39            3.39
# 2              3.39            3.39
# 3              2.39            2.39
# ...

# %%
chipo[(chipo['item_name'] == 'Canned Soda') & (chipo['quantity'] > 1)].order_id.nunique()
# Out:
# 18

# %% [markdown]
# ## III. Statistics & Data Engineering

# %%
chipo.drop_duplicates(subset=['item_name'], keep = 'last') # loai bo trung nhau torng Dl
# Out:
#       order_id  quantity                              item_name  \
# 521        217         1                           Crispy Tacos
# 673        279         1                                   Bowl
# 674        279         1      Chips and Mild Fresh Tomato Salsa
# 760        313         1                                Burrito
# 1415       575         1                                  Salad
# 1653       668         1                    Veggie Crispy Tacos
# 3321      1330         1                  Barbacoa Crispy Tacos
# 3502      1406         1                            Steak Salad
# 3669      1468         1                                   Izze
# 3750      1500         1                         Carnitas Salad
# 3780      1513         1     Chips and Roasted Chili Corn Salsa
# 3889      1559         2                      Veggie Soft Tacos
# 3905      1565         1     Chips and Roasted Chili-Corn Salsa
# 3989      1598         1                          Chicken Salad
# ...

# %% [markdown]
# **Reference**: Check out [Chipotle Exercises Video Tutorial](https://www.youtube.com/watch?v=lpuYZ5EUyS8&list=PLgJhDSE2ZLxaY_DigHeiIDC1cD09rXgJv&index=2) to watch a data scientist go through the exercises!

# %% [markdown]
# # <center> LESSON 10*: CONNECT PANDAS WITH SQL </center>

# %% [markdown]
# create table ACCOUNT (
#
#         ACCOUNT_ID integer not null auto_increment,
#         AVAIL_BALANCE float,
#         CLOSE_DATE date,
#         LAST_ACTIVITY_DATE date,
#         OPEN_DATE date not null,
#         PENDING_BALANCE float,
#         STATUS varchar(10),
#         CUST_ID integer,
#         OPEN_BRANCH_ID integer not null,
#         OPEN_EMP_ID integer not null,
#         PRODUCT_CD varchar(10) not null,
#         primary key (ACCOUNT_ID)
#     );
#
#    - always have ';' for finishing
#    - ACCOUNT_ID name of a column and integer not null auto_increment, is the type of database inside

# %% [markdown]
# - Step 1: Insstall SQLsever and SQL benhmark
# - Step 2: Crete Schema to create new database 'create banking;'
# - USe the SQL to creat the tables by writing the query
# - Case insensitive
# - Load script to generate databset inside the query

# %% [markdown]
# '' EER Diagram ''

# %% [markdown]
# - primary key: define the data insde each table
# - foregin key: create the relation between tables

# %%
# !pip install mysql-connector-python

# %%
import mysql.connector #MySQL

# %%
connection = mysql.connector.connect(
    host = 'localhost',
    user = 'root',
    password = 'Dat28121994',
    database = 'banking'
    ) #create  a connection between python and database

# %%
import pandas as pd 
import numpy as np

# %%
sql = 'SELECT * FROM ACCOUNT;'
account = pd.read_sql(sql,connection)

# %%
account.head()
# Out:
#    ACCOUNT_ID  AVAIL_BALANCE CLOSE_DATE LAST_ACTIVITY_DATE   OPEN_DATE  \
# 0           1        1057.75       None         2005-01-04  2000-01-15
# 1           2         500.00       None         2004-12-19  2000-01-15
# 2           3        3000.00       None         2004-06-30  2004-06-30
# 3           4        2258.02       None         2004-12-27  2001-03-12
# 4           5         200.00       None         2004-12-11  2001-03-12
#
#    PENDING_BALANCE  STATUS  CUST_ID  OPEN_BRANCH_ID  OPEN_EMP_ID PRODUCT_CD
# 0          1057.75  ACTIVE        1               2           10        CHK
# 1           500.00  ACTIVE        1               2           10        SAV
# 2          3000.00  ACTIVE        1               2           10         CD
# 3          2258.02  ACTIVE        2               2           10        CHK
# 4           200.00  ACTIVE        2               2           10        SAV

# %%
account.head(2)
# Out:
#    ACCOUNT_ID  AVAIL_BALANCE CLOSE_DATE LAST_ACTIVITY_DATE   OPEN_DATE  \
# 0           1        1057.75       None         2005-01-04  2000-01-15
# 1           2         500.00       None         2004-12-19  2000-01-15
#
#    PENDING_BALANCE  STATUS  CUST_ID  OPEN_BRANCH_ID  OPEN_EMP_ID PRODUCT_CD
# 0          1057.75  ACTIVE        1               2           10        CHK
# 1           500.00  ACTIVE        1               2           10        SAV

# %%
sql = 'SELECT * FROM ACCOUNT LIMIT 2;'
account = pd.read_sql(sql,connection)
account
# Out:
#    ACCOUNT_ID  AVAIL_BALANCE CLOSE_DATE LAST_ACTIVITY_DATE   OPEN_DATE  \
# 0           1        1057.75       None         2005-01-04  2000-01-15
# 1           2         500.00       None         2004-12-19  2000-01-15
#
#    PENDING_BALANCE  STATUS  CUST_ID  OPEN_BRANCH_ID  OPEN_EMP_ID PRODUCT_CD
# 0          1057.75  ACTIVE        1               2           10        CHK
# 1           500.00  ACTIVE        1               2           10        SAV

# %%
sql = 'SELECT * FROM ACCOUNT MAX;'
account = pd.read_sql(sql,connection)
account
# Out:
#     ACCOUNT_ID  AVAIL_BALANCE CLOSE_DATE LAST_ACTIVITY_DATE   OPEN_DATE  \
# 0            1        1057.75       None         2005-01-04  2000-01-15
# 1            2         500.00       None         2004-12-19  2000-01-15
# 2            3        3000.00       None         2004-06-30  2004-06-30
# 3            4        2258.02       None         2004-12-27  2001-03-12
# 4            5         200.00       None         2004-12-11  2001-03-12
# 5            7        1057.75       None         2004-11-30  2002-11-23
# 6            8        2212.50       None         2004-12-05  2002-12-15
# 7           10         534.12       None         2005-01-03  2003-09-12
# 8           11         767.77       None         2004-10-24  2000-01-15
# 9           12        5487.09       None         2004-11-11  2004-09-30
# 10          13        2237.97       None         2005-01-05  2004-01-27
# 11          14         122.37       None         2004-11-29  2002-08-24
# ...

# %% [markdown]
# MSSQL SEVER -sqlalchemy

# %%
# !pip install sqlalchemy

# %%
import  sqlalchemy as sa

# %%
connection = sa.create_engine('mssql://user-name/banking?truesred-connection=yes?')
# Out:
# zsh:1: number expected

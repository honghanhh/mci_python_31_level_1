# %%
1+1
# Out:
# 2

# %% [markdown]
# ### Phim tat
# - Run a command: Shift + Enter (hình tam giác next)
# - Convert cell mode into markdown: Esc + M
# - Convert markdown into cell code: Esc + Y
# - Move 1 cell above: A (mũi tên lên)
# - Move 1 cell below: B (mũi tên xuống)
# - Delete 1 cell: Esc + X
# - Add 1 cell: Esc + B

# %% [markdown]
# ![](https://www.google.com/url?sa=i&url=https%3A%2F%2Fkoladel.blogspot.com%2F2021%2F01%2Fson-ye-jin-hyun-bin-hyun-bin-son-ye-jin.html&psig=AOvVaw0EODAdqN6zbkb6tIBkJho1&ust=1623765076045000&source=images&cd=vfe&ved=0CAIQjRxqFwoTCODz07uil_ECFQAAAAAdAAAAABAO![image.png](attachment:0066ccc7-fd8c-4b1d-b124-8b4b0357d370.png)![image.png](attachment:2e4d140c-4169-474f-82af-7a8c8875a846.png)![image.png](attachment:144ecf4a-af5a-418c-87b5-8174f70bdbfe.png)![image.png](attachment:b16ced5a-800e-4df2-8f28-3e81237c59e5.png)

# %% [markdown]
# # Heading 1

# %% [markdown]
# ## Heading 2

# %% [markdown]
# ### 1. Part 1

# %% [markdown]
# *italics*

# %% [markdown]
# _italics_

# %% [markdown]
# **bold**

# %% [markdown]
# __bold__

# %% [markdown]
# <ins> underline <ins>

# %% [markdown]
# <p style="color:red"> This is a text </p>

# %% [markdown]
# <p> This is a text </p>

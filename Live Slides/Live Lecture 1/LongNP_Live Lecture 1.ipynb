# %% [markdown]
# Lesson 1
#
# Phím tắt
# - Run a command: Shift + Enter (Win) or Shift + Return (MacOS)
# - Convert cell code to Markdown: Esc + M
# - Convert Markdown to code cell: Esc + Y
# - Insert a cell above: A
# - Insert a cell below: B
# - Insert an image: ![](attachment:%25D0%25A3+%25D0%25BE%25D0%25BC%25D1%2583%25D1%2582%25D0%25B0+892.jpg)

# %% [markdown]
# # Heading 1
# ## Heading 2
# ### Headling 3
# Text format
# - *italic* or _italic_
# - ~strike~
# - **bold** or __bold__
# - <ins> underline </ins>
# - <p style="color:red"> Also response to css and html</p>

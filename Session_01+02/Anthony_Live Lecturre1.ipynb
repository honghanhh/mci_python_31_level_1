# %% [markdown]
# # PhimTat

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Heading 1

# %% [markdown]
# # 1 Chapter 1

# %% [markdown]
# **bold**

# %% [markdown]
# __bold__

# %% [markdown]
# *titalics*

# %% [markdown]
# <ins> underline </ins>

# %% [markdown]
# This is text

# %% [markdown]
# <p style="color:red"> this is a text </p>

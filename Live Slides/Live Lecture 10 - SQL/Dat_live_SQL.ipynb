# %% [markdown]
# # <center> LESSON 10*: CONNECT PANDAS WITH SQL </center>

# %%
#EER Diagram
#Primary key
#Foringe key 
#11, 1 nhiều, nhiều nhiều (mối quan hệ)

# %%
# !pip install mysql-connector-python
# Out:
# ...
#   Using cached mysql_connector_python-8.0.26-py2.py3-none-any.whl (324 kB)
# ...

# %%
import mysql.connector

# %%
connection = mysql.connector.connect(
    host = 'localhost',
    user = 'root',
    password= 'Dat28121994',
    database = 'banking'
)#creat connection between the python to databse using mysql

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sql = 'SELECT * FROM ACCOUNT;'
account = pd.read_sql(sql, connection)

# %%
account.head(10)
# Out:
#    ACCOUNT_ID  AVAIL_BALANCE CLOSE_DATE LAST_ACTIVITY_DATE   OPEN_DATE  \
# 0           1        1057.75       None         2005-01-04  2000-01-15
# 1           2         500.00       None         2004-12-19  2000-01-15
# 2           3        3000.00       None         2004-06-30  2004-06-30
# 3           4        2258.02       None         2004-12-27  2001-03-12
# 4           5         200.00       None         2004-12-11  2001-03-12
# 5           7        1057.75       None         2004-11-30  2002-11-23
# 6           8        2212.50       None         2004-12-05  2002-12-15
# 7          10         534.12       None         2005-01-03  2003-09-12
# 8          11         767.77       None         2004-10-24  2000-01-15
# 9          12        5487.09       None         2004-11-11  2004-09-30
#
#    PENDING_BALANCE  STATUS  CUST_ID  OPEN_BRANCH_ID  OPEN_EMP_ID PRODUCT_CD
# 0          1057.75  ACTIVE        1               2           10        CHK
# ...

# %%
#For sql sever MSQLSever 
# !pip install sqlalchemy
# Out:
# ...
#      |████████████████████████████████| 1.5 MB 2.4 MB/s eta 0:00:01
# ...
#   Using cached greenlet-1.1.1-cp37-cp37m-macosx_10_14_x86_64.whl (87 kB)
# ...

# %%
# import sqlalchemy as sa
# connection = sa.create_engine('mssql://sa/banking?trusted-connection=yes?')

# %%
connection = mysql.connector.connect(
    host = 'localhost',
    user = 'root',
    password= 'Dat28121994',
    database = 'lecture_schema'
)#creat connection between the python to databse using mysql

# %%
sql = 'SELECT * FROM ACCOUNT;'
account = pd.read_sql(sql, connection)
account
# Out:
#     ACCOUNT_ID  AVAIL_BALANCE CLOSE_DATE LAST_ACTIVITY_DATE   OPEN_DATE  \
# 0            1        1057.75       None         2005-01-04  2000-01-15
# 1            2         500.00       None         2004-12-19  2000-01-15
# 2            3        3000.00       None         2004-06-30  2004-06-30
# 3            4        2258.02       None         2004-12-27  2001-03-12
# 4            5         200.00       None         2004-12-11  2001-03-12
# 5            7        1057.75       None         2004-11-30  2002-11-23
# 6            8        2212.50       None         2004-12-05  2002-12-15
# 7           10         534.12       None         2005-01-03  2003-09-12
# 8           11         767.77       None         2004-10-24  2000-01-15
# 9           12        5487.09       None         2004-11-11  2004-09-30
# 10          13        2237.97       None         2005-01-05  2004-01-27
# 11          14         122.37       None         2004-11-29  2002-08-24
# ...

# %%
# !pip3 install pyodbc
# Out:
# ...
#      |████████████████████████████████| 68 kB 1.2 MB/s eta 0:00:01
# ...

# %%
import pyodbc
import pandas as pd
# Some other example server values are
# server = 'localhost\sqlexpress' # for a named instance
# server = 'myserver,port' # to specify an alternate port
server = 'localhost' 
database = 'LearnSQL' 
username = 'sa' 
password = 'Dat28121994'  
connection = pyodbc.connect('DRIVER={SQL Server};SERVER='+server+';DATABASE='+database+';UID='+username+';PWD='+ password)
connection= connection.cursor()
# select 26 rows from SQL table to insert in dataframe.
sql = "select * from sales.orders;"
df = pd.read_sql(sql,connection)
print(df.head(26))

# %% [markdown]
# - For moredetail you can check it at: https://dev.mysql.com/doc/connector-python/en/connector-python-example-connecting.html
#
# - SQLSEVER: https://datatofish.com/how-to-connect-python-to-sql-server-using-pyodbc/

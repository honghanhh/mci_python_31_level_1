# %%
1+1
# Out:
# 2

# %% [markdown]
# lesson 1

# %% [markdown]
# ![](https://afamilycdn.com/150157425591193600/2020/9/26/avatar1601092720030-1601092720726863651475.png)

# %% [markdown]
# ![](https://ss-images.saostar.vn/wp700/2016/01/04/180871/11.-T%C6%B0-th%E1%BA%BF-ng%E1%BB%A7-%C4%91%C3%A1ng-y%C3%AAu-c%E1%BB%A7a-c%C3%A1c-ch%C3%BA-ch%C3%B3.jpg)

# %% [markdown]
# ![maxresdefault.jpg](attachment:ed07b309-0418-4ac6-a98e-c39ac550bebb.jpg)

# %% [markdown]
# # heading

# %% [markdown]
# *italic*

# %% [markdown]
# **italic**

# %% [markdown]
# <ins>underline</ins>

# %% [markdown]
# <p> this is text </p>

# %% [markdown]
# <p style='color:red'> this is a text </p>

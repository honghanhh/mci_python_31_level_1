# %% [markdown]
# ![](https://upload.wikimedia.org/wikipedia/commons/thumb/e/ed/Pandas_logo.svg/1200px-Pandas_logo.svg.png)
# * for DataScience
# * Today we just forcus on practices with Pandas

# %% [markdown]
# # <center> LESSON 6: Practice with PANDAS </center>

# %% [markdown]
# ## I. Know your dataset

# %% [markdown]
# * This time we are going to pull data directly from the internet.
# * Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
# * All information: REF: [Pandas' Documentation](https://pandas.pydata.org/)

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd   
#!git clone https://github.com/justmarkham
#csv:comma-separated value 
#tsv:table_separtaed value 
#We use them together to avoid missunderstanding sometimes
#Why we do think about new characterise to separate them well>?
#! git clone https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'

# %%
chipo = pd.read_csv(url,sep='\t')

# %% [markdown]
# ### Step 3. Assign it to a variable called `chipo`.

# %%
chipo = pd.read_csv(url,sep='\t')
# We have csv command separated and tsv tab separated
# We have alot of way to separate it depending on whatever you wanna set for it 
# keyword: pd.read().. whatever you wanna have with pd.csv (sep= separate)

# %%
chipo = pd.read_csv(url, delimiter = '\t')
chipo
#In other way, we have dellimiter is the delimeter to determine what sep (separated) which we can change
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# 1                                          [Clementine]     $3.39
# 2                                               [Apple]     $3.39
# 3                                                   NaN     $2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# ...                                                 ...        ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75
#
# [4622 rows x 5 columns]

# %% [markdown]
# ### Step 4. See the first 10 entries

# %%
chipo.head(10) 
#Normally we use the head() to show what we have insde however we can show more and more depending on what you need
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 5  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 6                                                NaN     $1.69
# 7  [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75
# 8  [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...     $9.25
# 9  [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...     $9.25

# %%
chipo.loc[0:9,]
#It is the way to show clearly what we have inside what columns and observation you need
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 5  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 6                                                NaN     $1.69
# 7  [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75
# 8  [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...     $9.25
# 9  [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...     $9.25

# %%
chipo.loc[:9,:]#default: always from 0 and to the end
#We have otherways and not that with loc-inclusive value
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 5  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 6                                                NaN     $1.69
# 7  [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75
# 8  [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...     $9.25
# 9  [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...     $9.25

# %%
chipo.iloc[:10,:]
#I means that we are using index 
#iloc # exclusive value
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 5  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 6                                                NaN     $1.69
# 7  [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75
# 8  [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...     $9.25
# 9  [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...     $9.25

# %%
# note that loc take inclusive
#iloc take by using index therefore exclusive

# %% [markdown]
# ### Step 5. What is the number of observations in the dataset?

# %%
chipo.info()
#It is very good way to show all information which we need for datashowing
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
len(chipo)
# Out:
# 4622

# %%
len(chipo) #syntax: len(dataframe) 
#show how many columns(observation) you have
# Out:
# 4622

# %%
chipo.shape[0]
# Out:
# 4622

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %%
chipo.shape[1]
chipo.shape
#note that the shape() function will return 2 values of each array or table as pandas as follow as:
#Fist value shape[0] means the index(observation in numpy that is element) and columns
# Out:
# (4622, 5)

# %%
chipo.size
#Note that it looks like a list actually 
#It is the ways to show the dimension of a array as numpy which we learn before 
#Bisides we have shape() and size()
#for more information, you can check the dir with [method for method in dir(whatever) if not method.startswith('_')]
# Out:
# 23110

# %% [markdown]
# ### Step 7. Print the name of all the columns.

# %%
print(list(i for i in list(chipo.columns)))
# Out:
# ['order_id', 'quantity', 'item_name', 'choice_description', 'item_price']

# %%
print(chipo.columns.to_list()) #casting ép kiểu
print(chipo.columns.to_list()) 
#For more detail you can consider method ways also
# Out:
# ['order_id', 'quantity', 'item_name', 'choice_description', 'item_price']
# ['order_id', 'quantity', 'item_name', 'choice_description', 'item_price']

# %% [markdown]
# ### Step 8. How is the dataset indexed?

# %%
chipo.index #just check index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %% [markdown]
# ### Step 9. Which was the most-ordered item?

# %%
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
chipo.describe()
# Out:
#           order_id     quantity
# count  4622.000000  4622.000000
# mean    927.254868     1.075725
# std     528.890796     0.410186
# min       1.000000     1.000000
# 25%     477.250000     1.000000
# 50%     926.000000     1.000000
# 75%    1393.000000     1.000000
# max    1834.000000    15.000000

# %%
type(chipo.groupby('order_id').quantity.sum())
# Out:
# pandas.core.series.Series

# %%
chipo.groupby('order_id').quantity.sum().reset_index().rename(columns = {'quantity':'QUANTITY'})
# Out:
#       order_id  QUANTITY
# 0            1         4
# 1            2         2
# 2            3         2
# 3            4         2
# 4            5         2
# ...        ...       ...
# 1829      1830         2
# 1830      1831         3
# 1831      1832         2
# 1832      1833         2
# 1833      1834         3
#
# [1834 rows x 2 columns]

# %% [markdown]
# ### Step 10. For the most-ordered item, how many items were ordered?

# %%
chipo['item_name'].max()
# Out:
# 'Veggie Soft Tacos'

# %%
chipo['item_name']
# Out:
# 0                Chips and Fresh Tomato Salsa
# 1                                        Izze
# 2                            Nantucket Nectar
# 3       Chips and Tomatillo-Green Chili Salsa
# 4                                Chicken Bowl
#                         ...
# 4617                            Steak Burrito
# 4618                            Steak Burrito
# 4619                       Chicken Salad Bowl
# 4620                       Chicken Salad Bowl
# 4621                       Chicken Salad Bowl
# Name: item_name, Length: 4622, dtype: object

# %%
#We validate it basingf on item_name and quantity

# %% [markdown]
# 1. Quantity per item name

# %%
chipo.groupby('item_name').quantity.sum() #group1,2,3,4 basing (theo co che 3 buoc)
#Step 1: we separate it by key 
#step 2: we chose the value which we wanna use (quantity)
#step 3: The mathematic which we wanna use 
chipo.head()
chipo.groupby('item_name').head() #make the new dataframe 
chipo.groupby('item_name').order_id #-->dataframe 
chipo.groupby('item_name').order_id.sum() #-->serial 
chipo.groupby('item_name').order_id.sum().reset_index() #dataframe 
#chipo.groupby('item_name').order_id.sum().reset_index().rename(columns ={'quantity':'QUANTITY'})
#chipo.head()
# Out:
#                                 item_name  order_id
# 0                       6 Pack Soft Drink     52322
# 1                           Barbacoa Bowl     53972
# 2                        Barbacoa Burrito     74718
# 3                   Barbacoa Crispy Tacos      5613
# 4                     Barbacoa Salad Bowl      9708
# 5                     Barbacoa Soft Tacos     18725
# 6                           Bottled Water    175944
# 7                                    Bowl       472
# 8                                 Burrito      1550
# 9                             Canned Soda     76396
# 10                      Canned Soft Drink    304753
# 11                          Carnitas Bowl     62742
# 12                       Carnitas Burrito     51652
# 13                  Carnitas Crispy Tacos      5868
# 14                         Carnitas Salad      1500
# 15                    Carnitas Salad Bowl      6693
# 16                    Carnitas Soft Tacos     37673
# 17                           Chicken Bowl    713926
# 18                        Chicken Burrito    497303
# 19                   Chicken Crispy Tacos     47382
# 20                          Chicken Salad     10465
# 21                     Chicken Salad Bowl    117104
# 22                     Chicken Soft Tacos     98395
# 23                                  Chips    208004
# 24           Chips and Fresh Tomato Salsa    100419
# 25                    Chips and Guacamole    449959
# 26      Chips and Mild Fresh Tomato Salsa       279
# 27     Chips and Roasted Chili Corn Salsa     14999
# 28     Chips and Roasted Chili-Corn Salsa     17462
# 29  Chips and Tomatillo Green Chili Salsa     41170
# 30    Chips and Tomatillo Red Chili Salsa     45556
# 31  Chips and Tomatillo-Green Chili Salsa     21826
# 32    Chips and Tomatillo-Red Chili Salsa     18344
# 33                           Crispy Tacos       434
# 34                                   Izze     10587
# 35                       Nantucket Nectar     21814
# 36                                  Salad      1150
# 37                          Side of Chips     84769
# 38                             Steak Bowl    193752
# 39                          Steak Burrito    328437
# 40                     Steak Crispy Tacos     35818
# 41                            Steak Salad      2362
# 42                       Steak Salad Bowl     29590
# 43                       Steak Soft Tacos     50177
# 44                            Veggie Bowl     72270
# 45                         Veggie Burrito     80962
# 46                    Veggie Crispy Tacos       668
# 47                           Veggie Salad      7265
# 48                      Veggie Salad Bowl     17303
# 49                      Veggie Soft Tacos      5520

# %%
chipo.groupby('item_name').quantity.sum()
chipo.head()
chipo.groupby('item_name').head()
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 3363      1349         1                          Chicken Salad
# 3471      1395         1                           Veggie Salad
# 3502      1406         1                            Steak Salad
# 3749      1499         1                    Carnitas Salad Bowl
# 3750      1500         1                         Carnitas Salad
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# 1                                          [Clementine]     $3.39
# 2                                               [Apple]     $3.39
# 3                                                   NaN     $2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# ...                                                 ...        ...
# 3363  [Fresh Tomato Salsa (Mild), [Pinto Beans, Rice...     $8.49
# 3471  [[Tomatillo-Green Chili Salsa (Medium), Roaste...     $8.49
# 3502                        [[Lettuce, Fajita Veggies]]     $8.69
# 3749  [Roasted Chili Corn Salsa, [Fajita Vegetables,...    $11.89
# 3750  [[Fresh Tomato Salsa (Mild), Roasted Chili Cor...     $8.99
#
# [228 rows x 5 columns]

# %%
chipo.groupby('item_name').quantity.sum().nlargest().index[0]
#chipo.groupby('item_name').quantity.sum().nlargest().values[0]
# Out:
# 'Chicken Bowl'

# %%
chipo.groupby('item_name').quantity.sum().nsmallest(10).reset_index()
# Out:
#                            item_name  quantity
# 0                     Carnitas Salad         1
# 1  Chips and Mild Fresh Tomato Salsa         1
# 2                Veggie Crispy Tacos         1
# 3                       Crispy Tacos         2
# 4                              Salad         2
# 5                               Bowl         4
# 6                        Steak Salad         4
# 7                            Burrito         6
# 8                Carnitas Salad Bowl         6
# 9                       Veggie Salad         6

# %%
chipo.groupby('item_name').quantity.sum().nsmallest(1).values[0]
# Out:
# 1

# %%
chipo.groupby('item_name').quantity.sum().nsmallest(1).index[0]
# Out:
# 'Carnitas Salad'

# %%
smallest = chipo.groupby('item_name').quantity.sum().reset_index()
condition = smallest['quantity'] == 2
smallest[condition]
# Out:
#        item_name  quantity
# 33  Crispy Tacos         2
# 36         Salad         2

# %% [markdown]
# ||Serials value comparision||
# |-|-|-|
# |nlargest|nsmallers|sort_values|
# |top of leargest| top of smallest|sort all value as step by step|
# ||Asscesding will be used to choice the direction from max->min or min to max||

# %%
chipo.groupby('item_name').quantity.sum().sort_values(ascending = True) #min->max (are being at serials)
chipo.groupby('item_name').quantity.sum().sort_values(ascending = False) #max->min (are being at serials)
# Out:
# item_name
# Chicken Bowl                             761
# Chicken Burrito                          591
# Chips and Guacamole                      506
# Steak Burrito                            386
# Canned Soft Drink                        351
# Chips                                    230
# Steak Bowl                               221
# Bottled Water                            211
# Chips and Fresh Tomato Salsa             130
# Canned Soda                              126
# Chicken Salad Bowl                       123
# Chicken Soft Tacos                       120
# Side of Chips                            110
# Veggie Burrito                            97
# Barbacoa Burrito                          91
# Veggie Bowl                               87
# Carnitas Bowl                             71
# Barbacoa Bowl                             66
# Carnitas Burrito                          60
# Steak Soft Tacos                          56
# 6 Pack Soft Drink                         55
# Chips and Tomatillo Red Chili Salsa       50
# Chicken Crispy Tacos                      50
# Chips and Tomatillo Green Chili Salsa     45
# Carnitas Soft Tacos                       40
# Steak Crispy Tacos                        36
# Chips and Tomatillo-Green Chili Salsa     33
# Steak Salad Bowl                          31
# Nantucket Nectar                          29
# Chips and Tomatillo-Red Chili Salsa       25
# Barbacoa Soft Tacos                       25
# Chips and Roasted Chili Corn Salsa        23
# Izze                                      20
# Veggie Salad Bowl                         18
# Chips and Roasted Chili-Corn Salsa        18
# Barbacoa Crispy Tacos                     12
# Barbacoa Salad Bowl                       10
# Chicken Salad                              9
# Carnitas Crispy Tacos                      8
# Veggie Soft Tacos                          8
# Burrito                                    6
# Veggie Salad                               6
# Carnitas Salad Bowl                        6
# Bowl                                       4
# Steak Salad                                4
# Salad                                      2
# Crispy Tacos                               2
# Chips and Mild Fresh Tomato Salsa          1
# Carnitas Salad                             1
# Veggie Crispy Tacos                        1
# Name: quantity, dtype: int64

# %% [markdown]
# ### Step 11. What was the most ordered item in the choice_description column?

# %%
chipo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
type(chipo.isnull())
# Out:
# pandas.core.frame.DataFrame

# %%
chipo.isnull().sum()/len(chipo)
# Out:
# order_id              0.00000
# quantity              0.00000
# item_name             0.00000
# choice_description    0.26958
# item_price            0.00000
# dtype: float64

# %%
#missing percentage of datafram = Number of missiong per ...
chipo.isnull().sum()/len(chipo)*100
# Out:
# order_id               0.000000
# quantity               0.000000
# item_name              0.000000
# choice_description    26.958027
# item_price             0.000000
# dtype: float64

# %%
chipo.groupby('choice_description').quantity.sum().sort_values(ascending = False).index[0] #maximum value
# Out:
# '[Diet Coke]'

# %% [markdown]
# ### Step 12. How many items were ordered in total?

# %%
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
set(chipo.item_name)
chipo.item_name.unique()# check all different on item_name columns
# Out:
# array(['Chips and Fresh Tomato Salsa', 'Izze', 'Nantucket Nectar',
#        'Chips and Tomatillo-Green Chili Salsa', 'Chicken Bowl',
#        'Side of Chips', 'Steak Burrito', 'Steak Soft Tacos',
#        'Chips and Guacamole', 'Chicken Crispy Tacos',
#        'Chicken Soft Tacos', 'Chicken Burrito', 'Canned Soda',
#        'Barbacoa Burrito', 'Carnitas Burrito', 'Carnitas Bowl',
#        'Bottled Water', 'Chips and Tomatillo Green Chili Salsa',
#        'Barbacoa Bowl', 'Chips', 'Chicken Salad Bowl', 'Steak Bowl',
#        'Barbacoa Soft Tacos', 'Veggie Burrito', 'Veggie Bowl',
#        'Steak Crispy Tacos', 'Chips and Tomatillo Red Chili Salsa',
#        'Barbacoa Crispy Tacos', 'Veggie Salad Bowl',
#        'Chips and Roasted Chili-Corn Salsa',
#        'Chips and Roasted Chili Corn Salsa', 'Carnitas Soft Tacos',
#        'Chicken Salad', 'Canned Soft Drink', 'Steak Salad Bowl',
#        '6 Pack Soft Drink', 'Chips and Tomatillo-Red Chili Salsa', 'Bowl',
#        'Burrito', 'Crispy Tacos', 'Carnitas Crispy Tacos', 'Steak Salad',
#        'Chips and Mild Fresh Tomato Salsa', 'Veggie Soft Tacos',
#        'Carnitas Salad Bowl', 'Barbacoa Salad Bowl', 'Salad',
#        'Veggie Crispy Tacos', 'Veggie Salad', 'Carnitas Salad'],
#       dtype=object)

# %% [markdown]
# ### Step 13. Turn the item price into a float

# %% [markdown]
# #### Step 13.a. Check the item price type

# %%
chipo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
#object is mean that is string

# %%
type(chipo.item_price.iloc[0])
# Out:
# str

# %% [markdown]
# #### Step 13.b. Create a lambda function and change the type of item price

# %%
#casting 
chipo.item_price.iloc[1][1:]
# Out:
# '3.39 '

# %%
def convert_type(x):
    return float(x[1:]) #casting

# %%
chipo ['item_price_to_float'] = chipo.item_price.apply(convert_type) #add one colume more 
chipo.info()
chipo.head()
#chipo.item_price.apply excellent
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   order_id             4622 non-null   int64
#  1   quantity             4622 non-null   int64
#  2   item_name            4622 non-null   object
#  3   choice_description   3376 non-null   object
#  4   item_price           4622 non-null   object
#  5   item_price_to_float  4622 non-null   float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 216.8+ KB
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price  \
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
#
#    item_price_to_float
# 0                 2.39
# 1                 3.39
# 2                 3.39
# 3                 2.39
# 4                16.98

# %%
#pandas documentation more and more information  
book = 'https://bedford-computing.co.uk/learning/wp-content/uploads/2015/10/Python-for-Data-Analysis.pdf'

# %% [markdown]
# Rferance: [Python for DataAnalysis](https://bedford-computing.co.uk/learning/wp-content/uploads/2015/10/Python-for-Data-Analysis.pdf)

# %%
def convert_type(x):
    return float(x.replace('$','')) #import re
chipo ['item_price_to_float'] = chipo.item_price.apply(convert_type) #add one colume more

# %%
import re
dir(re)
# Out:
# ['A',
#  'ASCII',
#  'DEBUG',
#  'DOTALL',
#  'I',
#  'IGNORECASE',
#  'L',
#  'LOCALE',
#  'M',
#  'MULTILINE',
#  'Match',
#  'Pattern',
#  'RegexFlag',
#  'S',
#  'Scanner',
#  'T',
#  'TEMPLATE',
#  'U',
#  'UNICODE',
#  'VERBOSE',
#  'X',
#  '_MAXCACHE',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '__version__',
#  '_cache',
#  '_compile',
#  '_compile_repl',
#  '_expand',
#  '_locale',
#  '_pickle',
#  '_special_chars_map',
#  '_subx',
#  'compile',
#  'copyreg',
#  'enum',
#  'error',
#  'escape',
#  'findall',
#  'finditer',
#  'fullmatch',
#  'functools',
#  'match',
#  'purge',
#  'search',
#  'split',
#  'sre_compile',
#  'sre_parse',
#  'sub',
#  'subn',
#  'template']

# %%
#lamda is anoymious fuction

# %%
convert_type2 = lambda x:x.replace('$','')

# %%
chipo ['item_price_to_float'] = chipo.item_price.apply(convert_type2) #add one colume more 
chipo.head()
chipo.item_price_to_float.unique() #sort_value()...
# Out:
# array(['2.39 ', '3.39 ', '16.98 ', '10.98 ', '1.69 ', '11.75 ', '9.25 ',
#        '4.45 ', '8.75 ', '11.25 ', '8.49 ', '2.18 ', '8.99 ', '1.09 ',
#        '2.95 ', '2.15 ', '3.99 ', '22.50 ', '11.48 ', '17.98 ', '17.50 ',
#        '4.30 ', '5.90 ', '1.25 ', '23.78 ', '6.49 ', '11.08 ', '1.50 ',
#        '22.16 ', '32.94 ', '22.20 ', '10.58 ', '2.50 ', '23.50 ', '7.40 ',
#        '18.50 ', '3.00 ', '6.78 ', '11.89 ', '9.39 ', '4.00 ', '3.75 ',
#        '8.69 ', '2.29 ', '8.90 ', '3.27 ', '3.89 ', '8.19 ', '35.00 ',
#        '27.75 ', '11.80 ', '6.00 ', '26.25 ', '21.96 ', '4.36 ', '7.50 ',
#        '4.78 ', '13.35 ', '6.45 ', '5.07 ', '22.96 ', '7.17 ', '7.98 ',
#        '4.50 ', '26.07 ', '12.98 ', '35.25 ', '44.25 ', '10.50 ',
#        '33.75 ', '16.38 ', '13.52 ', '5.00 ', '15.00 ', '8.50 ', '17.80 ',
#        '1.99 ', '11.49 '], dtype=object)

# %% [markdown]
# #### Step 13.c. Check the item price type

# %%
#float

# %% [markdown]
# ### Step 14. How much was the revenue for the period in the dataset?

# %%
chipo.item_price_to_float.sum() 
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price  \
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
#
#   item_price_to_float
# 0               2.39
# 1               3.39
# 2               3.39
# 3               2.39
# 4              16.98

# %% [markdown]
# ### Step 15. How many orders were made in the period?

# %%
len(chipo.order_id.unique())
# Out:
# 1834

# %%
chipo.order_id.unique()
# Out:
# array([   1,    2,    3, ..., 1832, 1833, 1834])

# %%
len(chipo.order_id.unique())
# Out:
# 1834

# %% [markdown]
# ### Step 16. What is the average revenue amount per order?

# %%
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price  \
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
#
#   item_price_to_float
# 0               2.39
# 1               3.39
# 2               3.39
# 3               2.39
# 4              16.98

# %%
#Average revunu = Totoal value / SL order

# %%
chipo.item_price_to_float.sum()/len(chipo.order_id.unique())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-62-9fa3a2f516f2> in <module>
# ----> 1 chipo.item_price_to_float.sum()/len(chipo.order_id.unique())
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %% [markdown]
# ### Step 17. How many different items are sold?

# %%
chipo.info()

# %%
chipo['abc'] = chipo['item_price_to_float']/chipo['quantity'] #add a colum
chipo.head()

# %%
len(chipo.drop_duplicates(subset = ['item_name']))
# Out:
# 50

# %% [markdown]
# ## II. Filtering & Sorting

# %% [markdown]
# ### Step 18. How many products cost more than $10.00?

# %%
chipo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   order_id             4622 non-null   int64
#  1   quantity             4622 non-null   int64
#  2   item_name            4622 non-null   object
#  3   choice_description   3376 non-null   object
#  4   item_price           4622 non-null   object
#  5   item_price_to_float  4622 non-null   object
# dtypes: int64(2), object(4)
# memory usage: 216.8+ KB

# %%
len(chipo[chipo['item_price_to_float'] > 10])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-f5283116e7aa> in <module>
# ----> 1 len(chipo[chipo['item_price_to_float'] > 10])
#
# /opt/anaconda3/envs/anthony/lib/python3.7/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# /opt/anaconda3/envs/anthony/lib/python3.7/site-packages/pandas/core/arraylike.py in __gt__(self, other)
#      46     @unpack_zerodim_and_defer("__gt__")
#      47     def __gt__(self, other):
# ---> 48         return self._cmp_method(other, operator.gt)
#      49
#      50     @unpack_zerodim_and_defer("__ge__")
#
# /opt/anaconda3/envs/anthony/lib/python3.7/site-packages/pandas/core/series.py in _cmp_method(self, other, op)
#    5499
#    5500         with np.errstate(all="ignore"):
# -> 5501             res_values = ops.comparison_op(lvalues, rvalues, op)
#    5502
#    5503         return self._construct_result(res_values, name=res_name)
#
# /opt/anaconda3/envs/anthony/lib/python3.7/site-packages/pandas/core/ops/array_ops.py in comparison_op(left, right, op)
#     282
#     283     elif is_object_dtype(lvalues.dtype) or isinstance(rvalues, str):
# --> 284         res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     285
#     286     else:
#
# /opt/anaconda3/envs/anthony/lib/python3.7/site-packages/pandas/core/ops/array_ops.py in comp_method_OBJECT_ARRAY(op, x, y)
#      71         result = libops.vec_compare(x.ravel(), y.ravel(), op)
#      72     else:
# ---> 73         result = libops.scalar_compare(x.ravel(), y, op)
#      74     return result.reshape(x.shape)
#      75
#
# /opt/anaconda3/envs/anthony/lib/python3.7/site-packages/pandas/_libs/ops.pyx in pandas._libs.ops.scalar_compare()
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %% [markdown]
# ### Step 19. What is the price of each item?
# ###### Print a data frame with only two columns item_name and item_price and price per item

# %%
chipo[['item_name','item_price_to_float']].drop_duplicates()
# Out:
#                                   item_name item_price_to_float
# 0              Chips and Fresh Tomato Salsa               2.39
# 1                                      Izze               3.39
# 2                          Nantucket Nectar               3.39
# 3     Chips and Tomatillo-Green Chili Salsa               2.39
# 4                              Chicken Bowl              16.98
# ...                                     ...                 ...
# 4237                    Chips and Guacamole               8.50
# 4354                       Steak Soft Tacos              18.50
# 4489                    Chips and Guacamole              17.80
# 4509                                  Chips               1.99
# 4510                          Barbacoa Bowl              11.49
#
# [209 rows x 2 columns]

# %%
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price  \
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
#
#    item_price_to_float  price_per_item   abc
# 0                 2.39            2.39  2.39
# 1                 3.39            3.39  3.39
# 2                 3.39            3.39  3.39
# 3                 2.39            2.39  2.39
# 4                16.98            8.49  8.49

# %%
sample_chipo = chipo[['item_name','item_price_to_float']].drop_duplicates()
sample_chipo
# Out:
#                                   item_name item_price_to_float
# 0              Chips and Fresh Tomato Salsa               2.39
# 1                                      Izze               3.39
# 2                          Nantucket Nectar               3.39
# 3     Chips and Tomatillo-Green Chili Salsa               2.39
# 4                              Chicken Bowl              16.98
# ...                                     ...                 ...
# 4237                    Chips and Guacamole               8.50
# 4354                       Steak Soft Tacos              18.50
# 4489                    Chips and Guacamole              17.80
# 4509                                  Chips               1.99
# 4510                          Barbacoa Bowl              11.49
#
# [209 rows x 2 columns]

# %%
condition = sample_chipo.item_name == 'Chicken Bowl'
sample_chipo[sample_chipo['item_name'] == 'Chicken Bowl']
# Out:
#          item_name item_price_to_float
# 4     Chicken Bowl              16.98
# 5     Chicken Bowl              10.98
# 13    Chicken Bowl              11.25
# 19    Chicken Bowl               8.75
# 26    Chicken Bowl               8.49
# 154   Chicken Bowl              17.50
# 409   Chicken Bowl              32.94
# 1429  Chicken Bowl              22.50
# 1514  Chicken Bowl              26.25
# 1832  Chicken Bowl              21.96
# 2918  Chicken Bowl               8.19
# 2919  Chicken Bowl              10.58
# 4235  Chicken Bowl               8.50

# %%
chipo.groupby(['item_name','choice_description']).item_price_to_float.head(4)
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#          ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price_to_float, Length: 2687, dtype: object

# %%
chipo.groupby(['item_name','choice_description']).item_price_to_float.to_frame()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-95-060452a5e1f8> in <module>
# ----> 1 chipo.groupby(['item_name','choice_description']).item_price_to_float.to_frame()
#
# /opt/anaconda3/envs/anthony/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     909
#     910         raise AttributeError(
# --> 911             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     912         )
#     913
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'to_frame'

# %%
chipo.groupby(['item_name','choice_description']).item_price_to_float

# %%
pd.options.display.max_rows = None
pd.options.display.max_columns = None

# %% [markdown]
# ### Step 20. Sort by the name of the item

# %%
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price  \
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
#
#    item_price_to_float  price_per_item   abc
# 0                 2.39            2.39  2.39
# 1                 3.39            3.39  3.39
# 2                 3.39            3.39  3.39
# 3                 2.39            2.39  2.39
# 4                16.98            8.49  8.49

# %%
chipo.sort_values(by=['item_name','quantity'], ascending = [True, True]).head()
# Out:
#      order_id  quantity          item_name choice_description item_price  \
# 298       129         1  6 Pack Soft Drink           [Sprite]     $6.49
# 341       148         1  6 Pack Soft Drink        [Diet Coke]     $6.49
# 357       154         1  6 Pack Soft Drink             [Coke]     $6.49
# 388       168         1  6 Pack Soft Drink        [Diet Coke]     $6.49
# 417       182         1  6 Pack Soft Drink        [Diet Coke]     $6.49
#
#     item_price_to_float
# 298               6.49
# 341               6.49
# 357               6.49
# 388               6.49
# 417               6.49

# %%
chipo.sort_values(by=['item_name','quantity'],ascending = [True,True]).head()
# Out:
#      order_id  quantity          item_name choice_description item_price  \
# 298       129         1  6 Pack Soft Drink           [Sprite]     $6.49
# 341       148         1  6 Pack Soft Drink        [Diet Coke]     $6.49
# 357       154         1  6 Pack Soft Drink             [Coke]     $6.49
# 388       168         1  6 Pack Soft Drink        [Diet Coke]     $6.49
# 417       182         1  6 Pack Soft Drink        [Diet Coke]     $6.49
#
#     item_price_to_float
# 298               6.49
# 341               6.49
# 357               6.49
# 388               6.49
# 417               6.49

# %% [markdown]
# ### Step 21. What was the quantity of the most expensive item ordered?

# %%
#mon nao la mon dat nhat

# %%
chipo[chipo.item_price_to_float == chipo.item_price_to_float.max()].groupby(['item_name']).quantity.sum().sort_values(ascending=False)
# Out:
# item_name
# Steak Salad Bowl       10
# Barbacoa Salad Bowl     5
# Carnitas Salad Bowl     2
# Name: quantity, dtype: int64

# %% [markdown]
# ### Step 22. How many times was a Veggie Salad Bowl ordered?

# %%
chipo[chipo.item_name == 'Veggie Salad Bowl'].order_id.count()
#countfunctiontocalate howmany
# Out:
# 18

# %%
len(chipo[chipo.item_name == 'Veggie Salad Bowl'].order_id)
# Out:
# 18

# %%
#Cách 2
len(chipo[chipo.item_name == 'Veggie Salad Bowl'].order_id.unique())
# Out:
# 18

# %% [markdown]
# ### Step 23. How many times did someone order more than one Canned Soda?

# %%
chipo[(chipo['item_name'] == 'Canned Soda') & (chipo['quantity'] >1)].order_id.count()
# Out:
# 20

# %%
#Item_name 
len(chipo[(chipo['item_name'] == 'Canned Soda') & (chipo['quantity'] >1)].order_id)
# Out:
# 20

# %% [markdown]
# ## III. Statistics & Data Engineering

# %%
import pandas as pd

# %% [markdown]
# **Reference**: Check out [Chipotle Exercises Video Tutorial](https://www.youtube.com/watch?v=lpuYZ5EUyS8&list=PLgJhDSE2ZLxaY_DigHeiIDC1cD09rXgJv&index=2) to watch a data scientist go through the exercises!

# %%
chipo.drop_duplicates(subset=['item_name'],keep = 'last')
# Out:
#       order_id  quantity                              item_name  \
# 521        217         1                           Crispy Tacos
# 673        279         1                                   Bowl
# 674        279         1      Chips and Mild Fresh Tomato Salsa
# 760        313         1                                Burrito
# 1415       575         1                                  Salad
# 1653       668         1                    Veggie Crispy Tacos
# 3321      1330         1                  Barbacoa Crispy Tacos
# 3502      1406         1                            Steak Salad
# 3669      1468         1                                   Izze
# 3750      1500         1                         Carnitas Salad
# 3780      1513         1     Chips and Roasted Chili Corn Salsa
# 3889      1559         2                      Veggie Soft Tacos
# 3905      1565         1     Chips and Roasted Chili-Corn Salsa
# 3989      1598         1                          Chicken Salad
# 4007      1604         1  Chips and Tomatillo-Green Chili Salsa
# 4051      1621         1                            Canned Soda
# 4070      1629         1                          Side of Chips
# 4078      1632         1                       Nantucket Nectar
# 4084      1635         1                           Veggie Salad
# 4088      1637         1    Chips and Tomatillo-Red Chili Salsa
# 4239      1692         1                    Carnitas Salad Bowl
# 4271      1703         1                    Barbacoa Soft Tacos
# 4390      1751         1                    Barbacoa Salad Bowl
# 4450      1774         1                  Carnitas Crispy Tacos
# 4453      1775         1                   Chicken Crispy Tacos
# 4466      1779         1    Chips and Tomatillo Red Chili Salsa
# 4468      1780         1                            Veggie Bowl
# 4493      1787         1  Chips and Tomatillo Green Chili Salsa
# 4503      1790         1           Chips and Fresh Tomato Salsa
# 4518      1796         1                             Steak Bowl
# 4535      1803         1                      6 Pack Soft Drink
# 4549      1808         1                       Steak Soft Tacos
# 4554      1810         1                     Steak Crispy Tacos
# 4557      1811         1                    Carnitas Soft Tacos
# 4569      1817         1                        Chicken Burrito
# 4572      1818         1                       Steak Salad Bowl
# 4573      1818         1                      Veggie Salad Bowl
# 4578      1821         1                       Carnitas Burrito
# 4594      1825         1                          Barbacoa Bowl
# 4603      1827         1                       Barbacoa Burrito
# 4604      1828         1                           Chicken Bowl
# 4609      1829         1                      Canned Soft Drink
# 4611      1830         1                         Veggie Burrito
# 4612      1831         1                          Carnitas Bowl
# 4613      1831         1                                  Chips
# 4614      1831         1                          Bottled Water
# 4615      1832         1                     Chicken Soft Tacos
# 4616      1832         1                    Chips and Guacamole
# 4618      1833         1                          Steak Burrito
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price  \
# 521               [Adobo-Marinated and Grilled Chicken]     $7.40
# 673   [Adobo-Marinated and Grilled Steak, [Sour Crea...     $7.40
# 674                                                 NaN     $3.00
# 760   [White Rice, Adobo-Marinated and Grilled Steak...     $7.40
# 1415  [White Rice, Adobo-Marinated and Grilled Chick...     $7.40
# 1653  [Fresh Tomato Salsa (Mild), [Pinto Beans, Rice...     $8.49
# 3321  [[Fresh Tomato Salsa (Mild), Tomatillo-Green C...     $8.99
# 3502                        [[Lettuce, Fajita Veggies]]     $8.69
# 3669                                       [Blackberry]     $3.39
# 3750  [[Fresh Tomato Salsa (Mild), Roasted Chili Cor...     $8.99
# 3780                                                NaN     $2.95
# 3889  [Fresh Tomato Salsa (Mild), [Black Beans, Rice...    $16.98
# 3905                                                NaN     $2.39
# 3989  [Roasted Chili Corn (Medium), [Lettuce, Black ...     $8.19
# 4007                                                NaN     $2.39
# 4051                                           [Sprite]     $1.09
# 4070                                                NaN     $1.69
# 4078                                     [Peach Orange]     $3.39
# 4084  [[Fresh Tomato Salsa (Mild), Roasted Chili Cor...     $8.49
# 4088                                                NaN     $2.39
# 4239  [Tomatillo Green Chili Salsa, [Black Beans, Ch...    $11.89
# 4271  [Roasted Chili Corn Salsa, [Fajita Vegetables,...     $9.25
# 4390  [Tomatillo Green Chili Salsa, [Fajita Vegetabl...     $9.39
# 4450  [Fresh Tomato Salsa, [Pinto Beans, Sour Cream,...     $9.25
# 4453  [Tomatillo Red Chili Salsa, [Black Beans, Chee...     $8.75
# 4466                                                NaN     $2.95
# 4468  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...    $11.25
# 4493                                                NaN     $2.95
# 4503                                                NaN     $2.95
# 4518  [Tomatillo Red Chili Salsa, [Rice, Black Beans...    $11.75
# 4535                                         [Lemonade]     $6.49
# 4549  [Tomatillo Green Chili Salsa, [Rice, Pinto Bea...     $9.25
# 4554  [Roasted Chili Corn Salsa, [Fajita Vegetables,...    $11.75
# 4557  [Tomatillo Red Chili Salsa, [Fajita Vegetables...     $9.25
# 4569    [Fresh Tomato Salsa, [Fajita Vegetables, Rice]]     $8.75
# 4572  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $9.39
# 4573  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75
# 4578  [Tomatillo Green Chili Salsa, [Rice, Pinto Bea...     $9.25
# 4594  [Roasted Chili Corn Salsa, [Pinto Beans, Sour ...    $11.75
# 4603                      [Tomatillo Green Chili Salsa]     $9.25
# 4604  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...     $8.75
# 4609                                           [Sprite]     $1.25
# 4611  [Tomatillo Green Chili Salsa, [Rice, Fajita Ve...    $11.25
# 4612  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...     $9.25
# 4613                                                NaN     $2.15
# 4614                                                NaN     $1.50
# 4615   [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream]]     $8.75
# 4616                                                NaN     $4.45
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75
#
#      item_price_to_float
# 521                7.40
# 673                7.40
# 674                3.00
# 760                7.40
# 1415               7.40
# 1653               8.49
# 3321               8.99
# 3502               8.69
# 3669               3.39
# 3750               8.99
# 3780               2.95
# 3889              16.98
# 3905               2.39
# 3989               8.19
# 4007               2.39
# 4051               1.09
# 4070               1.69
# 4078               3.39
# 4084               8.49
# 4088               2.39
# 4239              11.89
# 4271               9.25
# 4390               9.39
# 4450               9.25
# 4453               8.75
# 4466               2.95
# 4468              11.25
# 4493               2.95
# 4503               2.95
# 4518              11.75
# 4535               6.49
# 4549               9.25
# 4554              11.75
# 4557               9.25
# 4569               8.75
# 4572               9.39
# 4573               8.75
# 4578               9.25
# 4594              11.75
# 4603               9.25
# 4604               8.75
# 4609               1.25
# 4611              11.25
# 4612               9.25
# 4613               2.15
# 4614               1.50
# 4615               8.75
# 4616               4.45
# 4618              11.75
# 4621               8.75

# %% [markdown]
# ### pyspark

# %%
#check missing value
chipo.isnull().sum()
# Out:
# order_id                  0
# quantity                  0
# item_name                 0
# choice_description     1246
# item_price                0
# item_price_to_float       0
# dtype: int64

# %%
chipo=chipo.fillna('[Unknown]')

# %%
chipo.head(3)
# Out:
#    order_id  quantity                     item_name choice_description  \
# 0         1         1  Chips and Fresh Tomato Salsa          [Unknown]
# 1         1         1                          Izze       [Clementine]
# 2         1         1              Nantucket Nectar            [Apple]
#
#   item_price item_price_to_float
# 0     $2.39                2.39
# 1     $3.39                3.39
# 2     $3.39                3.39
